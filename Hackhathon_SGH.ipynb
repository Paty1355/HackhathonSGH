# %% [markdown]
# <a href="https://colab.research.google.com/github/Paty1355/HackhathonSGH/blob/main/Hackhathon_SGH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json

# %%
import pandas as pd
import json

try:
    with open('paczkomaty.json', 'r') as f:
        data = [json.loads(line) for line in f]
except json.JSONDecodeError:
    with open('paczkomaty.json', 'r') as f:
          data = json.load(f)

paczkomaty_df = pd.DataFrame(data)

# %%
paczkomaty_df.head()
# Out:
#                                                 href     name  \
# 0  https://api-pl-points.easypack24.net/v1/points...   ADA01M
# 1  https://api-pl-points.easypack24.net/v1/points...   ADA01N
# 2  https://api-pl-points.easypack24.net/v1/points...  ADAM01N
# 3  https://api-pl-points.easypack24.net/v1/points...   ADK01M
# 4  https://api-pl-points.easypack24.net/v1/points...   ADM01A
#
#               type     status                                       location  \
# 0  [parcel_locker]  Operating  {'longitude': 22.26405, 'latitude': 51.73834}
# 1  [parcel_locker]  Operating  {'longitude': 22.25847, 'latitude': 51.74455}
# 2  [parcel_locker]  Operating  {'longitude': 18.08788, 'latitude': 52.26299}
# 3  [parcel_locker]  Operating  {'longitude': 22.69906, 'latitude': 50.25873}
# 4  [parcel_locker]  Operating  {'longitude': 20.63541, 'latitude': 52.06923}
#
#   location_type location_date    location_description location_description_1  \
# 0       Outdoor          None   Przy sklepie Lewiatan                   None
# 1       Outdoor          None    Przy sklepie Groszek                   None
# 2       Outdoor          None               Sklep ABC                   None
# 3       Outdoor          None  Parking z lewej strony                   None
# 4       Outdoor          None      Przy sklepie Beata                   None
#
#   location_description_2  ... recommended_low_interest_box_machines_list  \
# 0                   None  ...                                       None
# 1                Groszek  ...                                   [ADA01M]
# 2                   None  ...                           [GLN01M, GLN03M]
# 3                   None  ...                                       None
# 4                   None  ...                           [ADM03M, ADM02M]
#
#   apm_doubled location_247 operating_hours_extended agency  \
# 0        None         True       {'customer': None}    SDL
# 1        None         True       {'customer': None}    SDL
# 2        None         True       {'customer': None}    KON
# 3        None         True       {'customer': None}    RZ2
# 4        None         True       {'customer': None}    WA4
#
#                                            image_url easy_access_zone  \
# 0  https://static.easypack24.net/points/pl/images...             True
# 1  https://static.easypack24.net/points/pl/images...             True
# 2  https://static.easypack24.net/points/pl/images...             True
# 3  https://static.easypack24.net/points/pl/images...             True
# 4  https://static.easypack24.net/points/pl/images...             True
#
#    air_index_level  physical_type_mapped  physical_type_description
# 0             None                   004                       None
# 1             None                   005                       None
# 2             None                   005                       None
# 3             None                   004                       None
# 4             None                   003                       None
#
# [5 rows x 32 columns]

# %%
paczkomaty_df.isna().sum()/len(paczkomaty_df)
# Out:
# href                                          0.000000
# name                                          0.000000
# type                                          0.000000
# status                                        0.000000
# location                                      0.000000
# location_type                                 0.138755
# location_date                                 1.000000
# location_description                          0.003883
# location_description_1                        0.873386
# location_description_2                        0.850461
# distance                                      1.000000
# opening_hours                                 0.005238
# address                                       0.000000
# address_details                               0.000000
# phone_number                                  1.000000
# payment_point_descr                           0.003728
# functions                                     0.000000
# partner_id                                    0.000000
# is_next                                       0.000000
# payment_available                             0.000000
# payment_type                                  0.000000
# virtual                                       0.000000
# recommended_low_interest_box_machines_list    0.333867
# apm_doubled                                   0.894216
# location_247                                  0.000000
# operating_hours_extended                      0.000801
# agency                                        0.005208
# image_url                                     0.000000
# easy_access_zone                              0.000000
# air_index_level                               0.870798
# physical_type_mapped                          0.136382
# physical_type_description                     0.867501
# dtype: float64
